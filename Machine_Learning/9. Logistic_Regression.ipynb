# %% [markdown]
#     Multivariant Linear Regression
#         Multiple Features and Multiple Target

# %% [markdown]
#     Continuous Data --> Linear , Polynomial
#     Categorial Data --> Discrete Data --> Logistic Regression
#
#
#     Logistic Regression that also used to predict some dependent variables using independent variables
#     but the data which it handles is categorial data
#
#     This algorithm is for the classification
#
#
#
#     Categorial Data
#
#     Examples --> Gender (Male, Female) , girl and boy, andoid and ios, yes and no, cbse and state board,
#     fruits and vegetables, 0 and 1 , summer winter and autumn , types of transport, colors, 4 wheeler and 2 wheeler,
#     good better avg and best , language, fruad and non fruad, happy sad and neutral etc

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("ISLR_DATASET/default.csv",index_col=0)

# %%
data.head()
# Out:
#   default student      balance        income
# 1      No      No   729.526495  44361.625074
# 2      No     Yes   817.180407  12106.134700
# 3      No      No  1073.549164  31767.138947
# 4      No      No   529.250605  35704.493935
# 5      No      No   785.655883  38463.495879

# %%
age = np.random.normal(28,18,500)
income = age*0.5 + np.random.randn(500)

# %%
plt.plot(age,income,'o')

# %%
plt.rcParams['figure.dpi'] = 100

# %%
plt.style.use("ggplot")

# %%
plt.plot(data['income'],data['student'],'o')
plt.show()

# %%
plt.plot(data['balance'],data['student'],'o')
plt.show()

# %%
feature = data[['income']]
target = data['student'].map({"Yes":1,"No":0})

# %%
plt.plot(feature,target,'o')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,r2_score
from sklearn.linear_model import LinearRegression

# %%
feature.shape
# Out:
# (10000, 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 4 columns):
# default    10000 non-null object
# student    10000 non-null object
# balance    10000 non-null float64
# income     10000 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 390.6+ KB

# %%
data.describe()
# Out:
#             balance        income
# count  10000.000000  10000.000000
# mean     835.374886  33516.981876
# std      483.714985  13336.639563
# min        0.000000    771.967729
# 25%      481.731105  21340.462903
# 50%      823.636973  34552.644802
# 75%     1166.308386  43807.729272
# max     2654.322576  73554.233495

# %%
X_train,X_test,Y_train,Y_test = train_test_split(feature,target)

# %%
X_train[:5]
# Out:
#             income
# 7917  41883.414299
# 7745  23562.290612
# 2789  14101.290300
# 3413  43399.718282
# 8236  25802.276477

# %%
Y_train[:5]
# Out:
# 7917    0
# 7745    0
# 2789    1
# 3413    0
# 8236    1
# Name: student, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = model.predict(X_test)

# %%
Y_test[:5]
# Out:
# 9629    0
# 8930    0
# 9826    0
# 1187    1
# 6162    1
# Name: student, dtype: int64

# %%
pred[:5]
# Out:
# array([0.5030674 , 0.42525802, 0.10498878, 0.67470423, 0.70150851])

# %%
int(round(pred[0]))
# Out:
# 1

# %%
plt.plot(X_test,Y_test,'bo')
plt.plot(X_test,pred,'k--')
plt.show()
