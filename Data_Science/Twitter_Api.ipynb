# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# !pip install tweepy

# %%
from tweepy import OAuthHandler,Stream,StreamListener

# %%
import tweepy

# %%
# OAuth --> Authorization, Authentication

# %%
comsumer_key = "AA38o5Br6aQrgYE4ULjjKffE5"
consumer_token = "qO3HyF0ANgYixGKOtNqP9EJ4euq9Iy9eYKrtDXnXK8rOlgHljW"

access_key = "1305878831056650242-gLfpANIopRQf9AVKysnlbTIStYQxRW"
access_token = "OPeJTrakbh5kgJzJckl9IO76bzHMK6Xh5g4nXunaANef2"

# %%
auth = OAuthHandler(consumer_key,consumer_token)

# %%
auth

# %%
auth.set_access_token(access_key,access_token)

# %%
api = tweepy.API(auth)

# %%
api

# %%
print(dir(api))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_add_list_members', '_lookup_friendships', '_lookup_users', '_pack_image', '_remove_list_members', '_send_direct_message', '_statuses_lookup', 'add_list_member', 'add_list_members', 'api_root', 'auth', 'blocks', 'blocks_ids', 'cache', 'compression', 'configuration', 'create_block', 'create_favorite', 'create_friendship', 'create_list', 'create_mute', 'create_saved_search', 'destroy_block', 'destroy_direct_message', 'destroy_favorite', 'destroy_friendship', 'destroy_list', 'destroy_mute', 'destroy_saved_search', 'destroy_status', 'favorites', 'followers', 'followers_ids', 'friends', 'friends_ids', 'friendships_incoming', 'friendships_outgoing', 
# ...

# %%
api.followers()
# Out:
# []

# %%
api.followers_ids()
# Out:
# []

# %%
api

# %%
api.update_status(status="STAY SAFE AT HOME DURING CORONA")
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-95-384f8dfb2d8c> in <module>
# ----> 1 api.update_status(status="STAY SAFE AT HOME DURING CORONA")
#
# C:\Anaconda\lib\site-packages\tweepy\api.py in update_status(self, *args, **kwargs)
#     191             allowed_param=['status', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'auto_populate_reply_metadata', 'lat', 'long', 'source', 'place_id', 'display_coordinates'],
#     192             require_auth=True
# --> 193         )(post_data=post_data, *args, **kwargs)
#     194
#     195     def media_upload(self, filename, *args, **kwargs):
#
# C:\Anaconda\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ...

# %%
u = api.get_user("@narendramodi")

# %%
data = u._json

# %%
data['status']['text']
# Out:
# 'दरभंगा में एम्स के निर्माण से जहां बिहार के हेल्थ इंफ्रास्ट्रक्चर को मजबूती मिलेगी, वहीं स्वस्थ भारत के संकल्प को… https://t.co/ykxSSFjatU'

# %%
name = data['name']
loc = data['location']
desc = data['description']
follow = data['followers_count']
profile = data['profile_image_url_https']
bg_url = data['profile_background_image_url_https']
text = data['status']['text']
print(f"Name : {name}".center(80))
print(f"Location : {loc}".center(80))
print(f"Description : {desc}".center(80))
print(f"Profile Url : {profile}".center(80))
print(f"Background Image Url : {bg_url}".center(80))
print(f"Text : {text}".center(80))
# Out:
#                               Name : Narendra Modi
#                                 Location : India
#                      Description : Prime Minister of India
# Profile Url : https://pbs.twimg.com/profile_images/1249934092994375680/xX66NSZP_normal.jpg
#     Background Image Url : https://abs.twimg.com/images/themes/theme1/bg.png
# Text : दरभंगा में एम्स के निर्माण से जहां बिहार के हेल्थ इंफ्रास्ट्रक्चर को मजबूती मिलेगी, वहीं स्वस्थ भारत के संकल्प को… https://t.co/ykxSSFjatU

# %%
u.followers()
# Out:
# [User(_api=<tweepy.api.API object at 0x00000218116E1D08>, _json={'id': 1305886207641972736, 'id_str': '1305886207641972736', 'name': 'Kajoo kishor', 'screen_name': 'KajooKishor', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Tue Sep 15 15:08:59 +0000 2020', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile
# ...

# %%
u.followers()
# Out:
# [User(_api=<tweepy.api.API object at 0x00000218116E1D08>, _json={'id': 1305886605584945153, 'id_str': '1305886605584945153', 'name': 'SolAnkianilbhai', 'screen_name': 'ankianilbhai', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 7, 'listed_count': 0, 'created_at': 'Tue Sep 15 15:10:36 +0000 2020', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'pro
# ...

# %%
u.follow_request_sent
# Out:
# False

# %%
u.followers_count
# Out:
# 62330663

# %%
u.unfollow()
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-68-416e6e01ca60> in <module>
# ----> 1 u.unfollow()
#
# C:\Anaconda\lib\site-packages\tweepy\models.py in unfollow(self)
#     189
#     190     def unfollow(self):
# --> 191         self._api.destroy_friendship(user_id=self.id)
#     192         self.following = False
#     193
#
# C:\Anaconda\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# C:\Anaconda\lib\site-packages\tweepy\binder.py in execute(self)
#     231                     raise RateLimitError(error_msg, resp)
#     232                 else:
# --> 233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     234
# ...

# %%
### stream.....

# %%
api.followers()
# Out:
# []

# %%
api.auth

# %%
api.host
# Out:
# 'api.twitter.com'

# %%
api.me()
# Out:
# User(_api=<tweepy.api.API object at 0x00000218116E1D08>, _json={'id': 1305878831056650242, 'id_str': '1305878831056650242', 'name': 'navendra', 'screen_name': 'navendr71591617', 'location': '', 'profile_location': None, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 2, 'listed_count': 0, 'created_at': 'Tue Sep 15 14:39:20 +0000 2020', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_prof
# ...

# %%
api.update_status()
# Out:
# []
