# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data[data['Credit_CardNo'] == 12344]['Email']

# %%
df = pd.DataFrame({"Name":list("ABCDEFGHJK"),
                  "height":np.random.normal(140,5,10),
                  "weight":np.random.randint(70,100,10)
                  })

# %%
df
# Out:
#   Name      height  weight
# 0    A  130.026422      84
# 1    B  138.828672      83
# 2    C  147.819968      74
# 3    D  144.784893      77
# 4    E  136.118816      85
# 5    F  136.683602      93
# 6    G  138.300868      74
# 7    H  138.057229      99
# 8    J  142.350441      79
# 9    K  137.831474      77

# %%
df.drop("Name")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-c56ac686da3a> in <module>
# ----> 1 df.drop("Name")
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.drop(0)
# Out:
#   Name      height  weight
# 1    B  138.828672      83
# 2    C  147.819968      74
# 3    D  144.784893      77
# 4    E  136.118816      85
# 5    F  136.683602      93
# 6    G  138.300868      74
# 7    H  138.057229      99
# 8    J  142.350441      79
# 9    K  137.831474      77

# %%
df.drop(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-9dc77cf4558b> in <module>
# ----> 1 df.drop(10)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.index = df.Name

# %%
df
# Out:
#      Name      height  weight
# Name
# A       A  130.026422      84
# B       B  138.828672      83
# C       C  147.819968      74
# D       D  144.784893      77
# E       E  136.118816      85
# F       F  136.683602      93
# G       G  138.300868      74
# H       H  138.057229      99
# J       J  142.350441      79
# K       K  137.831474      77

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'J', 'K'], dtype='object', name='Name')

# %%
df.drop(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-16e123552181> in <module>
# ----> 1 df.drop(0)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.drop('G')
# Out:
#      Name      height  weight
# Name
# A       A  130.026422      84
# B       B  138.828672      83
# C       C  147.819968      74
# D       D  144.784893      77
# E       E  136.118816      85
# F       F  136.683602      93
# H       H  138.057229      99
# J       J  142.350441      79
# K       K  137.831474      77

# %%
df.drop("Name",axis=1)
#axis = 1, column
#axis= 0 , row
# Out:
#           height  weight
# Name
# A     130.026422      84
# B     138.828672      83
# C     147.819968      74
# D     144.784893      77
# E     136.118816      85
# F     136.683602      93
# G     138.300868      74
# H     138.057229      99
# J     142.350441      79
# K     137.831474      77

# %%
df.drop("A":"J")
# Out:
#   File "<ipython-input-14-b84470defe0e>", line 1
#     df.drop("A":"J")
#                ^
# SyntaxError: invalid syntax

# %%
df.drop(['A',"J","B"])
# Out:
#      Name      height  weight
# Name
# C       C  147.819968      74
# D       D  144.784893      77
# E       E  136.118816      85
# F       F  136.683602      93
# G       G  138.300868      74
# H       H  138.057229      99
# K       K  137.831474      77

# %%
df
# Out:
#      Name      height  weight
# Name
# A       A  130.026422      84
# B       B  138.828672      83
# C       C  147.819968      74
# D       D  144.784893      77
# E       E  136.118816      85
# F       F  136.683602      93
# G       G  138.300868      74
# H       H  138.057229      99
# J       J  142.350441      79
# K       K  137.831474      77

# %%
#drop always return

# %%
df = df.drop("Name",axis=1)

# %%
df
# Out:
#           height  weight
# Name
# A     130.026422      84
# B     138.828672      83
# C     147.819968      74
# D     144.784893      77
# E     136.118816      85
# F     136.683602      93
# G     138.300868      74
# H     138.057229      99
# J     142.350441      79
# K     137.831474      77

# %%
df
# Out:
#      Name      height  weight
# Name
# A       A  136.021678      94
# B       B  140.103893      74
# C       C  140.905052      79
# D       D  141.843800      98
# E       E  138.653420      70
# F       F  140.108769      72
# G       G  131.743463      75
# H       H  131.783724      93
# J       J  140.659685      88
# K       K  137.482127      80

# %%
df.drop("Name",inplace=True,axis=1)

# %%
df
# Out:
#           height  weight
# Name
# A     136.021678      94
# B     140.103893      74
# C     140.905052      79
# D     141.843800      98
# E     138.653420      70
# F     140.108769      72
# G     131.743463      75
# H     131.783724      93
# J     140.659685      88
# K     137.482127      80

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
mpg.drop("origin",inplace=True,axis=1)

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year                       name
# 0            70  chevrolet chevelle malibu
# 1            70          buick skylark 320
# ...

# %%
mpg['model_year'].value_counts().plot(kind="bar")

# %%
mpg.groupby("model_year").sum()
# Out:
#               mpg  cylinders  displacement  horsepower  weight  acceleration
# model_year
# 70          513.0        196        8161.0      4287.0   97811         375.5
# 71          595.0        156        5873.0      2890.0   83872         424.0
# 72          524.0        163        6114.5      3365.0   90656         423.5
# 73          684.0        255       10275.0      5219.0  136761         572.5
# 74          613.0        142        4637.0      2450.0   77704         437.5
# 75          608.0        168        6166.0      3032.0   95304         481.5
# 76          733.5        192        6725.0      3438.0  104677         542.0
# 77          654.5        153        5359.0      2942.0   83926         432.2
# 78          866.2        193        6401.0      3589.0  103025         569.0
# 79          727.7        169        5994.0      2935.0   88605         458.6
# 80          977.2        120        3359.0      2092.0   70663         491.1
# ...

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby("smoker").sum()
# Out:
#         total_bill     tip  size
# smoker
# Yes        1930.34  279.81   224
# No         2897.43  451.77   403

# %%
tips.groupby("day").sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
tips.groupby("day")['sex'].count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: sex, dtype: int64

# %%
tips.groupby("day")['sex'].value_counts()
# Out:
# day   sex
# Thur  Female    32
#       Male      30
# Fri   Male      10
#       Female     9
# Sat   Male      59
#       Female    28
# Sun   Male      58
#       Female    18
# Name: sex, dtype: int64

# %%
tips.groupby("day")['sex'].value_counts().index
# Out:
# MultiIndex([('Thur', 'Female'),
#             ('Thur',   'Male'),
#             ( 'Fri',   'Male'),
#             ( 'Fri', 'Female'),
#             ( 'Sat',   'Male'),
#             ( 'Sat', 'Female'),
#             ( 'Sun',   'Male'),
#             ( 'Sun', 'Female')],
#            names=['day', 'sex'])

# %%
tips.groupby("day")['sex'].value_counts().values
# Out:
# array([32, 30, 10,  9, 59, 28, 58, 18], dtype=int64)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby("time").count()
# Out:
#         total_bill  tip  sex  smoker  day  size
# time
# Lunch           68   68   68      68   68    68
# Dinner         176  176  176     176  176   176

# %%
tips.groupby("time").count().max()
# Out:
# total_bill    176
# tip           176
# sex           176
# smoker        176
# day           176
# size          176
# dtype: int64

# %%
tips.groupby(["time","smoker"]).count()
# Out:
#                total_bill  tip  sex  day  size
# time   smoker
# Lunch  Yes             23   23   23   23    23
#        No              45   45   45   45    45
# Dinner Yes             70   70   70   70    70
#        No             106  106  106  106   106

# %%
tips.groupby(["time","smoker"]).sum()
# Out:
#                total_bill     tip  size
# time   smoker
# Lunch  Yes         400.18   65.19    51
#        No          767.29  120.32   113
# Dinner Yes        1530.16  214.62   173
#        No         2130.14  331.45   290

# %%
tips.groupby(["time","smoker"]).cumsum()
#cumsum --> cummalative sum
# Out:
#      total_bill     tip  size
# 0         16.99    1.01     2
# 1         27.33    2.67     5
# 2         48.34    6.17     8
# 3         72.02    9.48    10
# 4         96.61   13.09    14
# ..          ...     ...   ...
# 239     2093.54  326.70   286
# 240     1507.49  212.62   171
# 241     1530.16  214.62   173
# 242     2111.36  328.45   288
# 243     2130.14  331.45   290
#
# [244 rows x 3 columns]

# %%
tips.cumsum()
# Out:
#     total_bill     tip                                                sex  \
# 0        16.99    1.01                                             Female
# 1        27.33    2.67                                         FemaleMale
# 2        48.34    6.17                                     FemaleMaleMale
# 3        72.02    9.48                                 FemaleMaleMaleMale
# 4        96.61   13.09                           FemaleMaleMaleMaleFemale
# ..         ...     ...                                                ...
# 239    4741.32  722.83  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 240     4768.5  724.83  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 241    4791.17  726.83  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 242    4808.99  728.58  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 243    4827.77  731.58  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
#
#                                                 smoker  \
# ...

# %%
tips['total_bill']/3
# Out:
# 0      5.663333
# 1      3.446667
# 2      7.003333
# 3      7.893333
# 4      8.196667
#          ...
# 239    9.676667
# 240    9.060000
# 241    7.556667
# 242    5.940000
# 243    6.260000
# Name: total_bill, Length: 244, dtype: float64

# %%
tips['per_person'] = tips['total_bill']/tips['size']

# %%
# 2 --> rows 
# 244 --> rows

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2    8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3    3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3    7.003333
# 3       23.68  3.31    Male     No  Sun  Dinner     2   11.840000
# 4       24.59  3.61  Female     No  Sun  Dinner     4    6.147500

# %%
newdf = tips.groupby(["time","smoker"]).sum()

# %%
newdf
# Out:
#                total_bill     tip  size  per_person
# time   smoker
# Lunch  Yes         400.18   65.19    51  182.606667
#        No          767.29  120.32   113  314.838833
# Dinner Yes        1530.16  214.62   173  630.247000
#        No         2130.14  331.45   290  797.035500

# %%
newdf.columns
# Out:
# Index(['total_bill', 'tip', 'size', 'per_person'], dtype='object')

# %%
newdf.index
# Out:
# MultiIndex([( 'Lunch', 'Yes'),
#             ( 'Lunch',  'No'),
#             ('Dinner', 'Yes'),
#             ('Dinner',  'No')],
#            names=['time', 'smoker'])

# %%
 (newdf['total_bill']/newdf['size']).plot(kind="bar")

# %%
newdf
# Out:
#                total_bill     tip  size  per_person
# time   smoker
# Lunch  Yes         400.18   65.19    51  182.606667
#        No          767.29  120.32   113  314.838833
# Dinner Yes        1530.16  214.62   173  630.247000
#        No         2130.14  331.45   290  797.035500

# %%
newdf.iloc[0,:]
# Out:
# total_bill    400.180000
# tip            65.190000
# size           51.000000
# per_person    182.606667
# Name: (Lunch, Yes), dtype: float64

# %%
newdf.T
# Out:
# time             Lunch                Dinner
# smoker             Yes          No       Yes         No
# total_bill  400.180000  767.290000  1530.160  2130.1400
# tip          65.190000  120.320000   214.620   331.4500
# size         51.000000  113.000000   173.000   290.0000
# per_person  182.606667  314.838833   630.247   797.0355

# %%
newdf.index
# Out:
# MultiIndex([( 'Lunch', 'Yes'),
#             ( 'Lunch',  'No'),
#             ('Dinner', 'Yes'),
#             ('Dinner',  'No')],
#            names=['time', 'smoker'])

# %%
newdf.loc[( 'Lunch', 'Yes')]
# Out:
# total_bill    400.180000
# tip            65.190000
# size           51.000000
# per_person    182.606667
# Name: (Lunch, Yes), dtype: float64

# %%
newdf
# Out:
#                total_bill     tip  size  per_person
# time   smoker
# Lunch  Yes         400.18   65.19    51  182.606667
#        No          767.29  120.32   113  314.838833
# Dinner Yes        1530.16  214.62   173  630.247000
#        No         2130.14  331.45   290  797.035500

# %%
newdf.loc[("Lunch","No"),"tip"]
# Out:
# 120.32000000000001

# %%
cum = tips[['total_bill','tip']].cumsum()

# %%
cum.loc[10]
# Out:
# total_bill    197.64
# tip            29.82
# Name: 10, dtype: float64

# %%
cum.loc[30]
# Out:
# total_bill    575.39
# tip            93.47
# Name: 30, dtype: float64

# %%
cum.loc[31]
# Out:
# total_bill    593.74
# tip            95.97
# Name: 31, dtype: float64

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  per_person
# 0         16.99  1.01  Female     No   Sun  Dinner     2    8.495000
# 1         10.34  1.66    Male     No   Sun  Dinner     3    3.446667
# 2         21.01  3.50    Male     No   Sun  Dinner     3    7.003333
# 3         23.68  3.31    Male     No   Sun  Dinner     2   11.840000
# 4         24.59  3.61  Female     No   Sun  Dinner     4    6.147500
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    9.676667
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   13.590000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   11.335000
# 242       17.82  1.75    Male     No   Sat  Dinner     2    8.910000
# 243       18.78  3.00  Female     No  Thur  Dinner     2    9.390000
#
# [244 rows x 8 columns]

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year                       name
# 0            70  chevrolet chevelle malibu
# 1            70          buick skylark 320
# ...

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# name            398 non-null object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
mpg.shape
# Out:
# (398, 8)

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year                       name
# 0          70  chevrolet chevelle malibu
# 1          70          buick skylark 320
# 2          70         plymouth satellite
# 3          70              amc rebel sst
# 4          70                ford torino

# %%
mpg[mpg['mpg'] == mpg['mpg'].max()]['cylinders']
# Out:
# 322    4
# Name: cylinders, dtype: int64

# %%
mpg[mpg['mpg'] == mpg['mpg'].min()]['cylinders']
# Out:
# 28    8
# Name: cylinders, dtype: int64

# %%
mpg['mpg'].value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 34.2     1
# 38.1     1
# 37.2     1
# 32.1     1
# 32.7     1
# Name: mpg, Length: 129, dtype: int64

# %%
mpg['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
mpg['model_year'].value_counts()
# Out:
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 81    29
# 80    29
# 79    29
# 70    29
# 77    28
# 72    28
# 71    28
# 74    27
# Name: model_year, dtype: int64

# %%
mpg.groupby("model_year").count()
# Out:
#             mpg  cylinders  displacement  horsepower  weight  acceleration  \
# model_year
# 70           29         29            29          29      29            29
# 71           28         28            28          27      28            28
# 72           28         28            28          28      28            28
# 73           40         40            40          40      40            40
# 74           27         27            27          26      27            27
# 75           30         30            30          30      30            30
# 76           34         34            34          34      34            34
# 77           28         28            28          28      28            28
# 78           36         36            36          36      36            36
# 79           29         29            29          29      29            29
# 80           29         29            29          27      29            29
# ...

# %%
mpg.groupby("model_year")['cylinders'].value_counts()
# Out:
# model_year  cylinders
# 70          8            18
#             4             7
#             6             4
# 71          4            13
#             6             8
#             8             7
# 72          4            14
#             8            13
#             3             1
# 73          8            20
#             4            11
#             6             8
#             3             1
# 74          4            15
#             6             7
#             8             5
# 75          4            12
#             6            12
#             8             6
# 76          4            15
#             6            10
#             8             9
# 77          4            14
#             8             8
#             6             5
#             3             1
# 78          4            17
#             6            12
#             8             6
#             5             1
# 79          4            12
#             8            10
# ...

# %%
#cyclinder 4 every year product
#70 = 7, 71 = 13, 21 = 14
#### tell me the answer??
# isha, vishal, ritik, abhishek, anav, tarun

# %%
mpg[mpg['cylinders'] == 4].count()
# Out:
# mpg             204
# cylinders       204
# displacement    204
# horsepower      199
# weight          204
# acceleration    204
# model_year      204
# name            204
# dtype: int64

# %%
mpg[mpg['cylinders'] == 4]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year                          name
# 14           70         toyota corona mark ii
# ...

# %%
mpg[mpg['cylinders'] == 4]['model_year'].value_counts()
# Out:
# 82    28
# 80    25
# 81    21
# 78    17
# 76    15
# 74    15
# 77    14
# 72    14
# 71    13
# 79    12
# 75    12
# 73    11
# 70     7
# Name: model_year, dtype: int64

# %%
mpg.groupby("model_year")["cylinders"]

# %%
mpg.groupby("model_year")["cylinders"]

# %%
mpg['cylinders'] == 4
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393     True
# 394     True
# 395     True
# 396     True
# 397     True
# Name: cylinders, Length: 398, dtype: bool

# %%
mpg[mpg['cylinders'] == 4]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year                          name
# 14           70         toyota corona mark ii
# ...

# %%
### groupby is used on df
### value_counts --> series
### count --> df, series

# %%
mpg[mpg['cylinders'] == 4].groupby("model_year")['cylinders'].count()
# Out:
# model_year
# 70     7
# 71    13
# 72    14
# 73    11
# 74    15
# 75    12
# 76    15
# 77    14
# 78    17
# 79    12
# 80    25
# 81    21
# 82    28
# Name: cylinders, dtype: int64

# %%
mpg['cylinders'].count()
# Out:
# 398

# %%
mpg['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year                       name
# 0          70  chevrolet chevelle malibu
# 1          70          buick skylark 320
# 2          70         plymouth satellite
# 3          70              amc rebel sst
# 4          70                ford torino

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2    8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3    3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3    7.003333
# 3       23.68  3.31    Male     No  Sun  Dinner     2   11.840000
# 4       24.59  3.61  Female     No  Sun  Dinner     4    6.147500

# %%
#### tell me the number of people giving maximum tip and are male???

# %%
tips['tip'].max()
# Out:
# 10.0

# %%
tips['tip'] == 10.0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: tip, Length: 244, dtype: bool

# %%
tips[tips['tip'] == 10.0]
# Out:
#      total_bill   tip   sex smoker  day    time  size  per_person
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3   16.936667

# %%
tips['tip'].min()
# Out:
# 1.0

# %%
tips[(tips['tip'] == tips['tip'].min()) & (tips['sex'] == "Male")].count()
# Out:
# total_bill    1
# tip           1
# sex           1
# smoker        1
# day           1
# time          1
# size          1
# per_person    1
# dtype: int64

# %%
tips[(tips['tip'] == tips['tip'].min()) & (tips['sex'] == "Female")].count()
# Out:
# total_bill    3
# tip           3
# sex           3
# smoker        3
# day           3
# time          3
# size          3
# per_person    3
# dtype: int64

# %%
### next function is apply which is used to perform any function on series or dataframe

# %%
tips.apply(np.cumsum)  #dataframe
# Out:
#      total_bill     tip                                                sex  \
# 0         16.99    1.01                                             Female
# 1         27.33    2.67                                         FemaleMale
# 2         48.34    6.17                                     FemaleMaleMale
# 3         72.02    9.48                                 FemaleMaleMaleMale
# 4         96.61   13.09                           FemaleMaleMaleMaleFemale
# ..          ...     ...                                                ...
# 239     4741.32  722.83  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 240     4768.50  724.83  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 241     4791.17  726.83  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 242     4808.99  728.58  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 243     4827.77  731.58  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
#
#                                                 smoker  \
# ...

# %%
mpg['mpg'].apply(np.cumsum)  #series
# Out:
# 0      [18.0]
# 1      [15.0]
# 2      [18.0]
# 3      [16.0]
# 4      [17.0]
#         ...
# 393    [27.0]
# 394    [44.0]
# 395    [32.0]
# 396    [28.0]
# 397    [31.0]
# Name: mpg, Length: 398, dtype: object

# %%
mpg['mpg']  #the values which are even i want True and False for the values which are odd

# %%
mpg['mpg']%2
# Out:
# 0      0.0
# 1      1.0
# 2      0.0
# 3      0.0
# 4      1.0
#       ...
# 393    1.0
# 394    0.0
# 395    0.0
# 396    0.0
# 397    1.0
# Name: mpg, Length: 398, dtype: float64

# %%
mpg['mpg'].apply(lambda x : x+1)
# Out:
# 0      19.0
# 1      16.0
# 2      19.0
# 3      17.0
# 4      18.0
#        ...
# 393    28.0
# 394    45.0
# 395    33.0
# 396    29.0
# 397    32.0
# Name: mpg, Length: 398, dtype: float64

# %%
mpg['mpg'].apply(lambda x : True if x%2 == 0 else False)
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 393    False
# 394     True
# 395     True
# 396     True
# 397    False
# Name: mpg, Length: 398, dtype: bool

# %%
mpg[mpg['mpg'].apply(lambda x : True if x%2 == 0 else False)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# ..    ...        ...           ...         ...     ...           ...
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
#
#      model_year                       name
# 0            70  chevrolet chevelle malibu
# 2            70         plymouth satellite
# ...

# %%
data = pd.read_csv("C://batches/online_batch/batch9am/Ecommerce Purchases.csv")

# %%
data.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
### kaggle --> datasets
### more repositories

# %%
data['CC Exp Date'].dtype
# Out:
# dtype('O')

# %%
def get_year(y):
    if y.split("/")[1] == "25":
        return True
    else:
        return False

# %%
get_year("11/24")
# Out:
# 24

# %%
data.shape
# Out:
# (10000, 14)

# %%
data['CC Exp Date'].apply(get_year)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: CC Exp Date, Length: 10000, dtype: bool

# %%
data[data['CC Exp Date'].apply(get_year)]['Credit Card']
# Out:
# 4       6011456623207998
# 5         30246185196287
# 7           561252141909
# 13      4603635169938574
# 15       180069437020404
#               ...
# 9955       4716539058450
# 9963    4295151255424068
# 9993      30025560104631
# 9994    3112186784121077
# 9996     210033169205009
# Name: Credit Card, Length: 1033, dtype: int64

# %%
data['Email'].apply(lambda x : x.split("@")[-1]).value_counts()[:5]  #where x will be the email values
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
### matches.csv (analysis), merge, nullvalues,outliers(z-index,iqr)
