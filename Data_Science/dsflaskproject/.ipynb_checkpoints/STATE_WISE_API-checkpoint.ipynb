# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests

# %%
url = "https://api.covidindiatracker.com/state_data.json"

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
data = requests.get(url)

# %%
data.status_code
# Out:
# 200

# %%
data.json()
# Out:
# [{'id': 'IN-MH',
#   'state': 'Maharashtra',
#   'active': 261798,
#   'confirmed': 990795,
#   'recovered': 700715,
#   'deaths': 28282,
#   'aChanges': 0,
#   'cChanges': 0,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [{'id': 'Pune',
#     'state': None,
#     'name': 'Pune',
#     'confirmed': 218502,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mumbai',
#     'state': None,
#     'name': 'Mumbai',
#     'confirmed': 163115,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Thane',
#     'state': None,
#     'name': 'Thane',
#     'confirmed': 150793,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Nashik',
#     'state': None,
#     'name': 'Nashik',
#     'confirmed': 50341,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Nagpur',
#     'state': None,
#     'name': 'Nagpur',
#     'confirmed': 44700,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Raigad',
#     'state': None,
#     'name': 'Raigad',
#     'confirmed': 38413,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Jalgaon',
#     'state': None,
#     'name': 'Jalgaon',
#     'confirmed': 34227,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kolhapur',
#     'state': None,
#     'name': 'Kolhapur',
#     'confirmed': 30609,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Palghar',
#     'state': None,
#     'name': 'Palghar',
#     'confirmed': 29478,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Aurangabad',
#     'state': None,
#     'name': 'Aurangabad',
#     'confirmed': 27667,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ahmednagar',
#     'state': None,
#     'name': 'Ahmednagar',
#     'confirmed': 26912,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Solapur',
#     'state': None,
#     'name': 'Solapur',
#     'confirmed': 25127,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Sangli',
#     'state': None,
#     'name': 'Sangli',
#     'confirmed': 21955,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Satara',
#     'state': None,
#     'name': 'Satara',
#     'confirmed': 21674,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Latur',
#     'state': None,
#     'name': 'Latur',
#     'confirmed': 11510,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Nanded',
#     'state': None,
#     'name': 'Nanded',
#     'confirmed': 10652,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Dhule',
#     'state': None,
#     'name': 'Dhule',
#     'confirmed': 10233,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Osmanabad',
#     'state': None,
#     'name': 'Osmanabad',
#     'confirmed': 8026,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Amravati',
#     'state': None,
#     'name': 'Amravati',
#     'confirmed': 7172,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Beed',
#     'state': None,
#     'name': 'Beed',
#     'confirmed': 6339,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ratnagiri',
#     'state': None,
#     'name': 'Ratnagiri',
#     'confirmed': 5632,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Jalna',
#     'state': None,
#     'name': 'Jalna',
#     'confirmed': 5595,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Akola',
#     'state': None,
#     'name': 'Akola',
#     'confirmed': 4937,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Chandrapur',
#     'state': None,
#     'name': 'Chandrapur',
#     'confirmed': 4697,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Buldhana',
#     'state': None,
#     'name': 'Buldhana',
#     'confirmed': 4686,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Yavatmal',
#     'state': None,
#     'name': 'Yavatmal',
#     'confirmed': 4600,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Parbhani',
#     'state': None,
#     'name': 'Parbhani',
#     'confirmed': 3811,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Nandurbar',
#     'state': None,
#     'name': 'Nandurbar',
#     'confirmed': 3606,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Gondia',
#     'state': None,
#     'name': 'Gondia',
#     'confirmed': 2769,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Washim',
#     'state': None,
#     'name': 'Washim',
#     'confirmed': 2442,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Bhandara',
#     'state': None,
#     'name': 'Bhandara',
#     'confirmed': 2408,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Sindhudurg',
#     'state': None,
#     'name': 'Sindhudurg',
#     'confirmed': 2157,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Wardha',
#     'state': None,
#     'name': 'Wardha',
#     'confirmed': 2019,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Hingoli',
#     'state': None,
#     'name': 'Hingoli',
#     'confirmed': 1946,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Gadchiroli',
#     'state': None,
#     'name': 'Gadchiroli',
#     'confirmed': 1059,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Other-States',
#     'state': None,
#     'name': 'Other States',
#     'confirmed': 986,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0},
#  {'id': 'IN-AP',
#   'state': 'Andhra Pradesh',
#   'active': 96191,
#   'confirmed': 547686,
#   'recovered': 446716,
#   'deaths': 4779,
#   'aChanges': -1147,
#   'cChanges': 9999,
#   'rChanges': 11069,
#   'dChanges': 77,
#   'districtData': [{'id': 'East-Godavari',
#     'state': None,
#     'name': 'East Godavari',
#     'confirmed': 73996,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 1499,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kurnool',
#     'state': None,
#     'name': 'Kurnool',
#     'confirmed': 50679,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 497,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'West-Godavari',
#     'state': None,
#     'name': 'West Godavari',
#     'confirmed': 48329,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 1081,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Anantapur',
#     'state': None,
#     'name': 'Anantapur',
#     'confirmed': 48105,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 557,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Chittoor',
#     'state': None,
#     'name': 'Chittoor',
#     'confirmed': 47509,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 1040,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Guntur',
#     'state': None,
#     'name': 'Guntur',
#     'confirmed': 44067,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 920,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Visakhapatnam',
#     'state': None,
#     'name': 'Visakhapatnam',
#     'confirmed': 42849,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 413,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Nellore',
#     'state': None,
#     'name': 'Nellore',
#     'confirmed': 41819,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 778,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kadapa',
#     'state': None,
#     'name': 'Kadapa',
#     'confirmed': 34788,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 698,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Prakasam',
#     'state': None,
#     'name': 'Prakasam',
#     'confirmed': 34508,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 901,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Srikakulam',
#     'state': None,
#     'name': 'Srikakulam',
#     'confirmed': 30942,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 570,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Vizianagaram',
#     'state': None,
#     'name': 'Vizianagaram',
#     'confirmed': 26790,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 594,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Krishna',
#     'state': None,
#     'name': 'Krishna',
#     'confirmed': 20410,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 451,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Other-States',
#     'state': None,
#     'name': 'Other States',
#     'confirmed': 2461,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Foreign-Evacuees',
#     'state': None,
#     'name': 'Foreign Evacuees',
#     'confirmed': 434,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': -1147,
#   'dchanges': 77,
#   'rchanges': 11069,
#   'cchanges': 9999},
#  {'id': 'IN-TN',
#   'state': 'Tamil Nadu',
#   'active': 48479,
#   'confirmed': 486052,
#   'recovered': 429416,
#   'deaths': 8157,
#   'aChanges': 0,
#   'cChanges': 0,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [{'id': 'Chennai',
#     'state': None,
#     'name': 'Chennai',
#     'confirmed': 145606,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Chengalpattu',
#     'state': None,
#     'name': 'Chengalpattu',
#     'confirmed': 29507,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Thiruvallur',
#     'state': None,
#     'name': 'Thiruvallur',
#     'confirmed': 27416,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Coimbatore',
#     'state': None,
#     'name': 'Coimbatore',
#     'confirmed': 20839,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kancheepuram',
#     'state': None,
#     'name': 'Kancheepuram',
#     'confirmed': 18967,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Cuddalore',
#     'state': None,
#     'name': 'Cuddalore',
#     'confirmed': 15473,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Madurai',
#     'state': None,
#     'name': 'Madurai',
#     'confirmed': 15118,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Salem',
#     'state': None,
#     'name': 'Salem',
#     'confirmed': 13590,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Virudhunagar',
#     'state': None,
#     'name': 'Virudhunagar',
#     'confirmed': 13576,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Theni',
#     'state': None,
#     'name': 'Theni',
#     'confirmed': 13520,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Thiruvannamalai',
#     'state': None,
#     'name': 'Thiruvannamalai',
#     'confirmed': 12442,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Vellore',
#     'state': None,
#     'name': 'Vellore',
#     'confirmed': 12234,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Thoothukudi',
#     'state': None,
#     'name': 'Thoothukudi',
#     'confirmed': 12066,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ranipet',
#     'state': None,
#     'name': 'Ranipet',
#     'confirmed': 11783,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Tirunelveli',
#     'state': None,
#     'name': 'Tirunelveli',
#     'confirmed': 10774,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kanniyakumari',
#     'state': None,
#     'name': 'Kanniyakumari',
#     'confirmed': 10615,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Viluppuram',
#     'state': None,
#     'name': 'Viluppuram',
#     'confirmed': 8990,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Trichy',
#     'state': None,
#     'name': 'Trichy',
#     'confirmed': 8540,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Thanjavur',
#     'state': None,
#     'name': 'Thanjavur',
#     'confirmed': 7906,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Dindigul',
#     'state': None,
#     'name': 'Dindigul',
#     'confirmed': 7681,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kallakurichi',
#     'state': None,
#     'name': 'Kallakurichi',
#     'confirmed': 7521,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Pudukkottai',
#     'state': None,
#     'name': 'Pudukkottai',
#     'confirmed': 7105,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Tenkasi',
#     'state': None,
#     'name': 'Tenkasi',
#     'confirmed': 6092,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ramanathapuram',
#     'state': None,
#     'name': 'Ramanathapuram',
#     'confirmed': 5132,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Thiruvarur',
#     'state': None,
#     'name': 'Thiruvarur',
#     'confirmed': 4816,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Sivagangai',
#     'state': None,
#     'name': 'Sivagangai',
#     'confirmed': 4399,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Erode',
#     'state': None,
#     'name': 'Erode',
#     'confirmed': 4205,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Tiruppur',
#     'state': None,
#     'name': 'Tiruppur',
#     'confirmed': 4066,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Nagapattinam',
#     'state': None,
#     'name': 'Nagapattinam',
#     'confirmed': 3716,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Tirupathur',
#     'state': None,
#     'name': 'Tirupathur',
#     'confirmed': 3506,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ariyalur',
#     'state': None,
#     'name': 'Ariyalur',
#     'confirmed': 3230,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Namakkal',
#     'state': None,
#     'name': 'Namakkal',
#     'confirmed': 3004,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Krishnagiri',
#     'state': None,
#     'name': 'Krishnagiri',
#     'confirmed': 2916,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Nilgiris',
#     'state': None,
#     'name': 'Nilgiris',
#     'confirmed': 2128,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Karur',
#     'state': None,
#     'name': 'Karur',
#     'confirmed': 2053,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Airport-Quarantine',
#     'state': None,
#     'name': 'Airport Quarantine',
#     'confirmed': 1802,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Dharmapuri',
#     'state': None,
#     'name': 'Dharmapuri',
#     'confirmed': 1796,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Perambalur',
#     'state': None,
#     'name': 'Perambalur',
#     'confirmed': 1494,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Railway-Quarantine',
#     'state': None,
#     'name': 'Railway Quarantine',
#     'confirmed': 428,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0},
#  {'id': 'IN-KA',
#   'state': 'Karnataka',
#   'active': 101556,
#   'confirmed': 430947,
#   'recovered': 322454,
#   'deaths': 6937,
#   'aChanges': 0,
#   'cChanges': 0,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [{'id': 'Bengaluru-Urban',
#     'state': None,
#     'name': 'Bengaluru Urban',
#     'confirmed': 160205,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ballari',
#     'state': None,
#     'name': 'Ballari',
#     'confirmed': 25404,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mysuru',
#     'state': None,
#     'name': 'Mysuru',
#     'confirmed': 23773,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Dakshina-Kannada',
#     'state': None,
#     'name': 'Dakshina Kannada',
#     'confirmed': 16112,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Belagavi',
#     'state': None,
#     'name': 'Belagavi',
#     'confirmed': 15606,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Dharwad',
#     'state': None,
#     'name': 'Dharwad',
#     'confirmed': 13867,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kalaburagi',
#     'state': None,
#     'name': 'Kalaburagi',
#     'confirmed': 13734,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Udupi',
#     'state': None,
#     'name': 'Udupi',
#     'confirmed': 13583,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Davanagere',
#     'state': None,
#     'name': 'Davanagere',
#     'confirmed': 12189,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Shivamogga',
#     'state': None,
#     'name': 'Shivamogga',
#     'confirmed': 11413,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Hassan',
#     'state': None,
#     'name': 'Hassan',
#     'confirmed': 10901,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Raichur',
#     'state': None,
#     'name': 'Raichur',
#     'confirmed': 8896,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Koppal',
#     'state': None,
#     'name': 'Koppal',
#     'confirmed': 8448,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Tumakuru',
#     'state': None,
#     'name': 'Tumakuru',
#     'confirmed': 8193,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Bagalkote',
#     'state': None,
#     'name': 'Bagalkote',
#     'confirmed': 7695,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mandya',
#     'state': None,
#     'name': 'Mandya',
#     'confirmed': 7691,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Vijayapura',
#     'state': None,
#     'name': 'Vijayapura',
#     'confirmed': 7570,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Gadag',
#     'state': None,
#     'name': 'Gadag',
#     'confirmed': 7115,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Uttara-Kannada',
#     'state': None,
#     'name': 'Uttara Kannada',
#     'confirmed': 6568,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Yadgir',
#     'state': None,
#     'name': 'Yadgir',
#     'confirmed': 6539,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Bengaluru-Rural',
#     'state': None,
#     'name': 'Bengaluru Rural',
#     'confirmed': 6002,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Haveri',
#     'state': None,
#     'name': 'Haveri',
#     'confirmed': 5949,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Chikkamagaluru',
#     'state': None,
#     'name': 'Chikkamagaluru',
#     'confirmed': 5652,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Chikkaballapura',
#     'state': None,
#     'name': 'Chikkaballapura',
#     'confirmed': 5369,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Bidar',
#     'state': None,
#     'name': 'Bidar',
#     'confirmed': 5200,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kolar',
#     'state': None,
#     'name': 'Kolar',
#     'confirmed': 4286,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Chitradurga',
#     'state': None,
#     'name': 'Chitradurga',
#     'confirmed': 4228,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ramanagara',
#     'state': None,
#     'name': 'Ramanagara',
#     'confirmed': 4023,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Chamarajanagara',
#     'state': None,
#     'name': 'Chamarajanagara',
#     'confirmed': 2837,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kodagu',
#     'state': None,
#     'name': 'Kodagu',
#     'confirmed': 1863,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Other-States',
#     'state': None,
#     'name': 'Other States',
#     'confirmed': 36,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0},
#  {'id': 'IN-UP',
#   'state': 'Uttar Pradesh',
#   'active': 67321,
#   'confirmed': 299045,
#   'recovered': 227442,
#   'deaths': 4282,
#   'aChanges': 1004,
#   'cChanges': 7016,
#   'rChanges': 5936,
#   'dChanges': 76,
#   'districtData': [{'id': 'Lucknow',
#     'state': None,
#     'name': 'Lucknow',
#     'confirmed': 37220,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 1184,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kanpur-Nagar',
#     'state': None,
#     'name': 'Kanpur Nagar',
#     'confirmed': 19158,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 413,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Prayagraj',
#     'state': None,
#     'name': 'Prayagraj',
#     'confirmed': 13494,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 352,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Gorakhpur',
#     'state': None,
#     'name': 'Gorakhpur',
#     'confirmed': 12294,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 249,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Varanasi',
#     'state': None,
#     'name': 'Varanasi',
#     'confirmed': 10287,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 232,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ghaziabad',
#     'state': None,
#     'name': 'Ghaziabad',
#     'confirmed': 10219,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 220,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Gautam-Buddha-Nagar',
#     'state': None,
#     'name': 'Gautam Buddha Nagar',
#     'confirmed': 9808,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 203,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Bareilly',
#     'state': None,
#     'name': 'Bareilly',
#     'confirmed': 8139,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 158,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Moradabad',
#     'state': None,
#     'name': 'Moradabad',
#     'confirmed': 6480,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 146,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Meerut',
#     'state': None,
#     'name': 'Meerut',
#     'confirmed': 6092,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 258,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Aligarh',
#     'state': None,
#     'name': 'Aligarh',
#     'confirmed': 6031,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 165,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Saharanpur',
#     'state': None,
#     'name': 'Saharanpur',
#     'confirmed': 5514,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 131,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Jhansi',
#     'state': None,
#     'name': 'Jhansi',
#     'confirmed': 5440,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 129,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Deoria',
#     'state': None,
#     'name': 'Deoria',
#     'confirmed': 4859,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 101,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Barabanki',
#     'state': None,
#     'name': 'Barabanki',
#     'confirmed': 4826,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 117,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ballia',
#     'state': None,
#     'name': 'Ballia',
#     'confirmed': 4764,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 79,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ayodhya',
#     'state': None,
#     'name': 'Ayodhya',
#     'confirmed': 4474,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 98,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Shahjahanpur',
#     'state': None,
#     'name': 'Shahjahanpur',
#     'confirmed': 4303,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 86,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Jaunpur',
#     'state': None,
#     'name': 'Jaunpur',
#     'confirmed': 4236,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 75,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Rampur',
#     'state': None,
#     'name': 'Rampur',
#     'confirmed': 4172,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 53,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kushinagar',
#     'state': None,
#     'name': 'Kushinagar',
#     'confirmed': 3992,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 100,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Agra',
#     'state': None,
#     'name': 'Agra',
#     'confirmed': 3834,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 101,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Maharajganj',
#     'state': None,
#     'name': 'Maharajganj',
#     'confirmed': 3750,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 113,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Azamgarh',
#     'state': None,
#     'name': 'Azamgarh',
#     'confirmed': 3667,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 42,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Hardoi',
#     'state': None,
#     'name': 'Hardoi',
#     'confirmed': 3366,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 108,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ghazipur',
#     'state': None,
#     'name': 'Ghazipur',
#     'confirmed': 3262,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 22,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Muzaffarnagar',
#     'state': None,
#     'name': 'Muzaffarnagar',
#     'confirmed': 3103,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 127,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Lakhimpur-Kheri',
#     'state': None,
#     'name': 'Lakhimpur Kheri',
#     'confirmed': 3100,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 109,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Gonda',
#     'state': None,
#     'name': 'Gonda',
#     'confirmed': 3068,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 39,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mathura',
#     'state': None,
#     'name': 'Mathura',
#     'confirmed': 2976,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 64,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Etawah',
#     'state': None,
#     'name': 'Etawah',
#     'confirmed': 2887,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 80,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Basti',
#     'state': None,
#     'name': 'Basti',
#     'confirmed': 2852,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 33,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Pilibhit',
#     'state': None,
#     'name': 'Pilibhit',
#     'confirmed': 2836,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 31,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Sitapur',
#     'state': None,
#     'name': 'Sitapur',
#     'confirmed': 2804,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 40,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Bulandshahr',
#     'state': None,
#     'name': 'Bulandshahr',
#     'confirmed': 2797,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 64,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Unnao',
#     'state': None,
#     'name': 'Unnao',
#     'confirmed': 2713,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 78,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Siddharthnagar',
#     'state': None,
#     'name': 'Siddharthnagar',
#     'confirmed': 2588,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 25,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Sultanpur',
#     'state': None,
#     'name': 'Sultanpur',
#     'confirmed': 2561,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 76,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Pratapgarh',
#     'state': None,
#     'name': 'Pratapgarh',
#     'confirmed': 2542,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 78,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Bahraich',
#     'state': None,
#     'name': 'Bahraich',
#     'confirmed': 2473,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 27,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Chandauli',
#     'state': None,
#     'name': 'Chandauli',
#     'confirmed': 2453,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': -20,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Bijnor',
#     'state': None,
#     'name': 'Bijnor',
#     'confirmed': 2274,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 39,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Sant-Kabir-Nagar',
#     'state': None,
#     'name': 'Sant Kabir Nagar',
#     'confirmed': 2204,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 21,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Sonbhadra',
#     'state': None,
#     'name': 'Sonbhadra',
#     'confirmed': 2139,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 75,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Amroha',
#     'state': None,
#     'name': 'Amroha',
#     'confirmed': 2081,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 57,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mainpuri',
#     'state': None,
#     'name': 'Mainpuri',
#     'confirmed': 2067,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 67,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Budaun',
#     'state': None,
#     'name': 'Budaun',
#     'confirmed': 2058,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 70,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Hapur',
#     'state': None,
#     'name': 'Hapur',
#     'confirmed': 2040,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 34,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Rae-Bareli',
#     'state': None,
#     'name': 'Rae Bareli',
#     'confirmed': 2021,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 65,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Firozabad',
#     'state': None,
#     'name': 'Firozabad',
#     'confirmed': 1996,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 37,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kannauj',
#     'state': None,
#     'name': 'Kannauj',
#     'confirmed': 1966,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 21,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mau',
#     'state': None,
#     'name': 'Mau',
#     'confirmed': 1958,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 24,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mirzapur',
#     'state': None,
#     'name': 'Mirzapur',
#     'confirmed': 1945,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 49,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Lalitpur',
#     'state': None,
#     'name': 'Lalitpur',
#     'confirmed': 1881,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 57,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Sambhal',
#     'state': None,
#     'name': 'Sambhal',
#     'confirmed': 1845,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 39,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Amethi',
#     'state': None,
#     'name': 'Amethi',
#     'confirmed': 1836,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 58,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Fatehpur',
#     'state': None,
#     'name': 'Fatehpur',
#     'confirmed': 1692,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 44,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Jalaun',
#     'state': None,
#     'name': 'Jalaun',
#     'confirmed': 1660,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 49,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Auraiya',
#     'state': None,
#     'name': 'Auraiya',
#     'confirmed': 1658,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 43,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Farrukhabad',
#     'state': None,
#     'name': 'Farrukhabad',
#     'confirmed': 1652,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 31,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Shamli',
#     'state': None,
#     'name': 'Shamli',
#     'confirmed': 1591,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 30,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kanpur-Dehat',
#     'state': None,
#     'name': 'Kanpur Dehat',
#     'confirmed': 1469,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 17,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Banda',
#     'state': None,
#     'name': 'Banda',
#     'confirmed': 1354,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 42,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Bhadohi',
#     'state': None,
#     'name': 'Bhadohi',
#     'confirmed': 1330,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 12,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Etah',
#     'state': None,
#     'name': 'Etah',
#     'confirmed': 1277,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 37,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Balrampur',
#     'state': None,
#     'name': 'Balrampur',
#     'confirmed': 1200,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 11,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kaushambi',
#     'state': None,
#     'name': 'Kaushambi',
#     'confirmed': 1189,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 32,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ambedkar-Nagar',
#     'state': None,
#     'name': 'Ambedkar Nagar',
#     'confirmed': 1125,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 40,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kasganj',
#     'state': None,
#     'name': 'Kasganj',
#     'confirmed': 1125,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 21,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Baghpat',
#     'state': None,
#     'name': 'Baghpat',
#     'confirmed': 1042,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 31,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Chitrakoot',
#     'state': None,
#     'name': 'Chitrakoot',
#     'confirmed': 904,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 22,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Shrawasti',
#     'state': None,
#     'name': 'Shrawasti',
#     'confirmed': 810,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': -6,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Hamirpur',
#     'state': None,
#     'name': 'Hamirpur',
#     'confirmed': 807,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 21,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Hathras',
#     'state': None,
#     'name': 'Hathras',
#     'confirmed': 773,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 20,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mahoba',
#     'state': None,
#     'name': 'Mahoba',
#     'confirmed': 642,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 20,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 1004,
#   'dchanges': 76,
#   'rchanges': 5936,
#   'cchanges': 7016},
#  {'id': 'IN-DL',
#   'state': 'Delhi',
#   'active': 26907,
#   'confirmed': 209748,
#   'recovered': 178154,
#   'deaths': 4687,
#   'aChanges': 1491,
#   'cChanges': 4266,
#   'rChanges': 2754,
#   'dChanges': 21,
#   'districtData': [{'id': 'Central-Delhi',
#     'state': None,
#     'name': 'Central Delhi',
#     'confirmed': 184,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'South-East-Delhi',
#     'state': None,
#     'name': 'South East Delhi',
#     'confirmed': 130,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'West-Delhi',
#     'state': None,
#     'name': 'West Delhi',
#     'confirmed': 122,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'South-Delhi',
#     'state': None,
#     'name': 'South Delhi',
#     'confirmed': 70,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'North-Delhi',
#     'state': None,
#     'name': 'North Delhi',
#     'confirmed': 60,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Shahdara',
#     'state': None,
#     'name': 'Shahdara',
#     'confirmed': 48,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'South-West-Delhi',
#     'state': None,
#     'name': 'South West Delhi',
#     'confirmed': 42,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'East-Delhi',
#     'state': None,
#     'name': 'East Delhi',
#     'confirmed': 38,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'New-Delhi',
#     'state': None,
#     'name': 'New Delhi',
#     'confirmed': 37,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
# ...
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Lohit',
#     'state': None,
#     'name': 'Lohit',
#     'confirmed': 182,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Upper-Subansiri',
#     'state': None,
#     'name': 'Upper Subansiri',
#     'confirmed': 163,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Lower-Siang',
#     'state': None,
#     'name': 'Lower Siang',
#     'confirmed': 137,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Lower-Dibang-Valley',
#     'state': None,
#     'name': 'Lower Dibang Valley',
#     'confirmed': 116,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Lower-Subansiri',
#     'state': None,
#     'name': 'Lower Subansiri',
#     'confirmed': 91,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Upper-Siang',
#     'state': None,
#     'name': 'Upper Siang',
#     'confirmed': 85,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Anjaw',
#     'state': None,
#     'name': 'Anjaw',
#     'confirmed': 77,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Longding',
#     'state': None,
#     'name': 'Longding',
#     'confirmed': 73,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Lepa-Rada',
#     'state': None,
#     'name': 'Lepa Rada',
#     'confirmed': 69,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Siang',
#     'state': None,
#     'name': 'Siang',
#     'confirmed': 42,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Pakke-Kessang',
#     'state': None,
#     'name': 'Pakke Kessang',
#     'confirmed': 28,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Shi-Yomi',
#     'state': None,
#     'name': 'Shi Yomi',
#     'confirmed': 21,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kurung-Kumey',
#     'state': None,
#     'name': 'Kurung Kumey',
#     'confirmed': 12,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kra-Daadi',
#     'state': None,
#     'name': 'Kra Daadi',
#     'confirmed': 4,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kamle',
#     'state': None,
#     'name': 'Kamle',
#     'confirmed': 3,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Upper-Dibang-Valley',
#     'state': None,
#     'name': 'Upper Dibang Valley',
#     'confirmed': 1,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0},
#  {'id': 'IN-NL',
#   'state': 'Nagaland',
#   'active': 1157,
#   'confirmed': 4946,
#   'recovered': 3781,
#   'deaths': 8,
#   'aChanges': 305,
#   'cChanges': 310,
#   'rChanges': 5,
#   'dChanges': 0,
#   'districtData': [{'id': 'Dimapur',
#     'state': None,
#     'name': 'Dimapur',
#     'confirmed': 2376,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 176,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kohima',
#     'state': None,
#     'name': 'Kohima',
#     'confirmed': 1531,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 127,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Peren',
#     'state': None,
#     'name': 'Peren',
#     'confirmed': 348,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 1,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mon',
#     'state': None,
#     'name': 'Mon',
#     'confirmed': 324,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 1,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Zunheboto',
#     'state': None,
#     'name': 'Zunheboto',
#     'confirmed': 119,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 3,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Tuensang',
#     'state': None,
#     'name': 'Tuensang',
#     'confirmed': 73,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Others',
#     'state': None,
#     'name': 'Others',
#     'confirmed': 46,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mokokchung',
#     'state': None,
#     'name': 'Mokokchung',
#     'confirmed': 37,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 1,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Wokha',
#     'state': None,
#     'name': 'Wokha',
#     'confirmed': 35,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 1,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Phek',
#     'state': None,
#     'name': 'Phek',
#     'confirmed': 34,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kiphire',
#     'state': None,
#     'name': 'Kiphire',
#     'confirmed': 16,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Longleng',
#     'state': None,
#     'name': 'Longleng',
#     'confirmed': 7,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 305,
#   'dchanges': 0,
#   'rchanges': 5,
#   'cchanges': 310},
#  {'id': 'IN-AN',
#   'state': 'Andaman and Nicobar Islands',
#   'active': 293,
#   'confirmed': 3465,
#   'recovered': 3121,
#   'deaths': 51,
#   'aChanges': 0,
#   'cChanges': 0,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [{'id': 'South-Andaman',
#     'state': None,
#     'name': 'South Andaman',
#     'confirmed': 51,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'North-and-Middle-Andaman',
#     'state': None,
#     'name': 'North and Middle Andaman',
#     'confirmed': 1,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0},
#  {'id': 'IN-ML',
#   'state': 'Meghalaya',
#   'active': 1434,
#   'confirmed': 3296,
#   'recovered': 1842,
#   'deaths': 20,
#   'aChanges': 0,
#   'cChanges': 0,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [{'id': 'East-Khasi-Hills',
#     'state': None,
#     'name': 'East Khasi Hills',
#     'confirmed': 2026,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'West-Garo-Hills',
#     'state': None,
#     'name': 'West Garo Hills',
#     'confirmed': 530,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Ribhoi',
#     'state': None,
#     'name': 'Ribhoi',
#     'confirmed': 302,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'East-Jaintia-Hills',
#     'state': None,
#     'name': 'East Jaintia Hills',
#     'confirmed': 147,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'East-Garo-Hills',
#     'state': None,
#     'name': 'East Garo Hills',
#     'confirmed': 103,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'West-Khasi-Hills',
#     'state': None,
#     'name': 'West Khasi Hills',
#     'confirmed': 62,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'West-Jaintia-Hills',
#     'state': None,
#     'name': 'West Jaintia Hills',
#     'confirmed': 39,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'South-Garo-Hills',
#     'state': None,
#     'name': 'South Garo Hills',
#     'confirmed': 37,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'North-Garo-Hills',
#     'state': None,
#     'name': 'North Garo Hills',
#     'confirmed': 28,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'South-West-Garo-Hills',
#     'state': None,
#     'name': 'South West Garo Hills',
#     'confirmed': 20,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'South-West-Khasi-Hills',
#     'state': None,
#     'name': 'South West Khasi Hills',
#     'confirmed': 2,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0},
#  {'id': 'IN-LK',
#   'state': 'Ladakh',
#   'active': 776,
#   'confirmed': 3177,
#   'recovered': 2366,
#   'deaths': 35,
#   'aChanges': 0,
#   'cChanges': 0,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [{'id': 'Leh',
#     'state': None,
#     'name': 'Leh',
#     'confirmed': 1770,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kargil',
#     'state': None,
#     'name': 'Kargil',
#     'confirmed': 1407,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0},
#  {'id': 'IN-SK',
#   'state': 'Sikkim',
#   'active': 532,
#   'confirmed': 2009,
#   'recovered': 1470,
#   'deaths': 7,
#   'aChanges': 0,
#   'cChanges': 0,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [{'id': 'East-Sikkim',
#     'state': None,
#     'name': 'East Sikkim',
#     'confirmed': 1446,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'South-Sikkim',
#     'state': None,
#     'name': 'South Sikkim',
#     'confirmed': 475,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'West-Sikkim',
#     'state': None,
#     'name': 'West Sikkim',
#     'confirmed': 87,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'North-Sikkim',
#     'state': None,
#     'name': 'North Sikkim',
#     'confirmed': 1,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0},
#  {'id': 'IN-DD',
#   'state': 'Daman and Diu',
#   'active': 144,
#   'confirmed': 1366,
#   'recovered': 1221,
#   'deaths': 1,
#   'aChanges': 0,
#   'cChanges': 0,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0},
#  {'id': 'IN-MZ',
#   'state': 'Mizoram',
#   'active': 603,
#   'confirmed': 1353,
#   'recovered': 750,
#   'deaths': 0,
#   'aChanges': 20,
#   'cChanges': 20,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [{'id': 'Aizawl',
#     'state': None,
#     'name': 'Aizawl',
#     'confirmed': 887,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 16,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Kolasib',
#     'state': None,
#     'name': 'Kolasib',
#     'confirmed': 203,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 3,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Lunglei',
#     'state': None,
#     'name': 'Lunglei',
#     'confirmed': 124,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 1,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Mamit',
#     'state': None,
#     'name': 'Mamit',
#     'confirmed': 33,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Lawngtlai',
#     'state': None,
#     'name': 'Lawngtlai',
#     'confirmed': 31,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Saiha',
#     'state': None,
#     'name': 'Saiha',
#     'confirmed': 30,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Serchhip',
#     'state': None,
#     'name': 'Serchhip',
#     'confirmed': 19,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Champhai',
#     'state': None,
#     'name': 'Champhai',
#     'confirmed': 17,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Saitual',
#     'state': None,
#     'name': 'Saitual',
#     'confirmed': 4,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Khawzawl',
#     'state': None,
#     'name': 'Khawzawl',
#     'confirmed': 3,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'},
#    {'id': 'Hnahthial',
#     'state': None,
#     'name': 'Hnahthial',
#     'confirmed': 2,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'NONE'}],
#   'achanges': 20,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 20},
#  {'id': 'IN-DN',
#   'state': 'Dadra and Nagar Haveli',
#   'active': 158,
#   'confirmed': 1247,
#   'recovered': 1088,
#   'deaths': 1,
#   'aChanges': 0,
#   'cChanges': 0,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [{'id': 'Dadra-and-Nagar-Haveli',
#     'state': None,
#     'name': 'Dadra and Nagar Haveli',
#     'confirmed': 228,
#     'recovered': None,
#     'deaths': None,
#     'oldConfirmed': 0,
#     'oldRecovered': None,
#     'oldDeaths': None,
#     'zone': 'ORANGE'}],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0},
#  {'id': 'IN-LD',
#   'state': 'Lakshadweep',
#   'active': 0,
#   'confirmed': 0,
#   'recovered': 0,
#   'deaths': 0,
#   'aChanges': 0,
#   'cChanges': 0,
#   'rChanges': 0,
#   'dChanges': 0,
#   'districtData': [],
#   'achanges': 0,
#   'dchanges': 0,
#   'rchanges': 0,
#   'cchanges': 0}]

# %%
r = requests.get("https://covid-india-api.herokuapp.com/v1/api")

# %%
r.json()
# Out:
# {'data': 'fetching.. please try again in a minute'}

# %%
d = requests.get('https://covid-19india-api.herokuapp.com/v2.0/helpline_numbers')

# %%
d.json()
# Out:
# ["Now, you don't have to mention version number. Visit Homepage for more API endpoints",
#  {'contact_details': [{'helpline_number': '0866-2410978',
#     'state_or_UT': 'Andhra Pradesh'},
#    {'helpline_number': '9436055743', 'state_or_UT': 'Arunachal Pradesh'},
#    {'helpline_number': '6913347770', 'state_or_UT': 'Assam'},
#    {'helpline_number': '104', 'state_or_UT': 'Bihar'},
#    {'helpline_number': '104', 'state_or_UT': 'Chhattisgarh'},
#    {'helpline_number': '104', 'state_or_UT': 'Goa'},
#    {'helpline_number': '104', 'state_or_UT': 'Gujarat'},
#    {'helpline_number': '8558893911', 'state_or_UT': 'Haryana'},
#    {'helpline_number': '104', 'state_or_UT': 'Himachal Pradesh'},
#    {'helpline_number': '104', 'state_or_UT': 'Jharkhand'},
#    {'helpline_number': '104', 'state_or_UT': 'Karnataka'},
#    {'helpline_number': '0471-2552056', 'state_or_UT': 'Kerala'},
#    {'helpline_number': '104', 'state_or_UT': 'Madhya Pradesh'},
#    {'helpline_number': '020-26127394', 'state_or_UT': 'Maharashtra'},
#    {'helpline_number': '3852411668', 'state_or_UT': 'Manipur'},
#    {'helpline_number': '108', 'state_or_UT': 'Meghalaya'},
#    {'helpline_number': '102', 'state_or_UT': 'Mizoram'},
#    {'helpline_number': '7005539653', 'state_or_UT': 'Nagaland'},
#    {'helpline_number': '9439994859', 'state_or_UT': 'Odisha'},
#    {'helpline_number': '104', 'state_or_UT': 'Punjab'},
#    {'helpline_number': '0141-2225624', 'state_or_UT': 'Rajasthan'},
#    {'helpline_number': '104', 'state_or_UT': 'Sikkim'},
#    {'helpline_number': '044-29510500', 'state_or_UT': 'Tamil Nadu'},
#    {'helpline_number': '104', 'state_or_UT': 'Telangana'},
#    {'helpline_number': '0381-2315879', 'state_or_UT': 'Tripura'},
#    {'helpline_number': '104', 'state_or_UT': 'Uttarakhand'},
#    {'helpline_number': '18001805145', 'state_or_UT': 'Uttar Pradesh'},
#    {'helpline_number': '1800313444222 , 03323412600',
#     'state_or_UT': 'West Bengal'},
#    {'helpline_number': '03192-232102',
#     'state_or_UT': 'Andaman and Nicobar Islands'},
#    {'helpline_number': '9779558282', 'state_or_UT': 'Chandigarh'},
#    {'helpline_number': '104',
#     'state_or_UT': 'Dadra and Nagar Haveli and Daman & Diu'},
#    {'helpline_number': '011-22307145', 'state_or_UT': 'Delhi'},
#    {'helpline_number': '01912520982, 0194-2440283',
#     'state_or_UT': 'Jammu & Kashmir'},
#    {'helpline_number': '01982256462', 'state_or_UT': 'Ladakh'},
#    {'helpline_number': '104', 'state_or_UT': 'Lakshadweep'},
#    {'helpline_number': '104', 'state_or_UT': 'Puducherry'}],
#   'helpline_email': 'ncov2019@gov.in',
#   'helpline_number': '+91-11-23978046',
#   'source': 'https://www.mohfw.gov.in/pdf/coronvavirushelplinenumber.pdf',
#   'toll_free': '1075'}]

# %%
d = requests.get("https://covid-19india-api.herokuapp.com/v2.0/state_data")

# %%
d = d.json()

# %%
type(d)
# Out:
# list

# %%
d[1]['state_data']
# Out:
# [{'active': 293,
#   'active_rate': 8.46,
#   'confirmed': 3465,
#   'death_rate': 1.47,
#   'deaths': 51,
#   'recovered': 3121,
#   'recovered_rate': 90.07,
#   'state': 'Andaman and Nicobar'},
#  {'active': 97338,
#   'active_rate': 18.1,
#   'confirmed': 537687,
#   'death_rate': 0.87,
#   'deaths': 4702,
#   'recovered': 435647,
#   'recovered_rate': 81.02,
#   'state': 'Andhra Pradesh'},
#  {'active': 1658,
#   'active_rate': 29.23,
#   'confirmed': 5672,
#   'death_rate': 0.16,
#   'deaths': 9,
#   'recovered': 4005,
#   'recovered_rate': 70.61,
#   'state': 'Arunachal Pradesh'},
#  {'active': 29690,
#   'active_rate': 21.86,
#   'confirmed': 135805,
#   'death_rate': 0.3,
#   'deaths': 414,
#   'recovered': 105701,
#   'recovered_rate': 77.83,
#   'state': 'Assam'},
#  {'active': 15239,
#   'active_rate': 9.92,
#   'confirmed': 153568,
#   'death_rate': 0.51,
#   'deaths': 785,
#   'recovered': 137544,
#   'recovered_rate': 89.57,
#   'state': 'Bihar'},
#  {'active': 2573,
#   'active_rate': 36.83,
#   'confirmed': 6987,
#   'death_rate': 1.19,
#   'deaths': 83,
#   'recovered': 4331,
#   'recovered_rate': 61.99,
#   'state': 'Chandigarh'},
#  {'active': 29332,
#   'active_rate': 52.68,
#   'confirmed': 55680,
#   'death_rate': 0.89,
#   'deaths': 493,
#   'recovered': 25855,
#   'recovered_rate': 46.43,
#   'state': 'Chhattisgarh'},
#  {'active': 294,
#   'active_rate': 11.01,
#   'confirmed': 2671,
#   'death_rate': 0.07,
#   'deaths': 2,
#   'recovered': 2375,
#   'recovered_rate': 88.92,
#   'state': 'Dadra and Nagar Haveli and Daman and Diu'},
#  {'active': 25416,
#   'active_rate': 12.37,
#   'confirmed': 205482,
#   'death_rate': 2.27,
#   'deaths': 4666,
#   'recovered': 175400,
#   'recovered_rate': 85.36,
#   'state': 'Delhi'},
#  {'active': 5030,
#   'active_rate': 21.97,
#   'confirmed': 22890,
#   'death_rate': 1.17,
#   'deaths': 268,
#   'recovered': 17592,
#   'recovered_rate': 76.85,
#   'state': 'Goa'},
#  {'active': 16198,
#   'active_rate': 14.8,
#   'confirmed': 109465,
#   'death_rate': 2.89,
#   'deaths': 3164,
#   'recovered': 90103,
#   'recovered_rate': 82.31,
#   'state': 'Gujarat'},
#  {'active': 18332,
#   'active_rate': 21.33,
#   'confirmed': 85944,
#   'death_rate': 1.06,
#   'deaths': 907,
#   'recovered': 66705,
#   'recovered_rate': 77.61,
#   'state': 'Haryana'},
#  {'active': 2723,
#   'active_rate': 32.16,
#   'confirmed': 8466,
#   'death_rate': 0.78,
#   'deaths': 66,
#   'recovered': 5677,
#   'recovered_rate': 67.06,
#   'state': 'Himachal Pradesh'},
#  {'active': 14074,
#   'active_rate': 28.64,
#   'confirmed': 49134,
#   'death_rate': 1.72,
#   'deaths': 845,
#   'recovered': 34215,
#   'recovered_rate': 69.64,
#   'state': 'Jammu and Kashmir'},
#  {'active': 15447,
#   'active_rate': 26.6,
#   'confirmed': 58079,
#   'death_rate': 0.89,
#   'deaths': 517,
#   'recovered': 42115,
#   'recovered_rate': 72.51,
#   'state': 'Jharkhand'},
#  {'active': 101556,
#   'active_rate': 23.57,
#   'confirmed': 430947,
#   'death_rate': 1.61,
#   'deaths': 6937,
#   'recovered': 322454,
#   'recovered_rate': 74.82,
#   'state': 'Karnataka'},
#  {'active': 26292,
#   'active_rate': 26.49,
#   'confirmed': 99266,
#   'death_rate': 0.4,
#   'deaths': 396,
#   'recovered': 72578,
#   'recovered_rate': 73.11,
#   'state': 'Kerala'},
#  {'active': 775,
#   'active_rate': 24.39,
#   'confirmed': 3177,
#   'death_rate': 1.13,
#   'deaths': 36,
#   'recovered': 2366,
#   'recovered_rate': 74.47,
#   'state': 'Ladakh'},
#  {'active': 0,
#   'active_rate': 0,
#   'confirmed': 0,
#   'death_rate': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'recovered_rate': 0,
#   'state': 'Lakshadweep'},
#  {'active': 261798,
#   'active_rate': 26.42,
#   'confirmed': 990795,
#   'death_rate': 2.85,
#   'deaths': 28282,
#   'recovered': 700715,
#   'recovered_rate': 70.72,
#   'state': 'Maharashtra'},
#  {'active': 1633,
#   'active_rate': 21.86,
#   'confirmed': 7470,
#   'death_rate': 0.59,
#   'deaths': 44,
#   'recovered': 5793,
#   'recovered_rate': 77.55,
#   'state': 'Manipur'},
#  {'active': 1434,
#   'active_rate': 43.51,
#   'confirmed': 3296,
#   'death_rate': 0.61,
#   'deaths': 20,
#   'recovered': 1842,
#   'recovered_rate': 55.89,
#   'state': 'Meghalaya'},
#  {'active': 583,
#   'active_rate': 43.74,
#   'confirmed': 1333,
#   'death_rate': 0.0,
#   'deaths': 0,
#   'recovered': 750,
#   'recovered_rate': 56.26,
#   'state': 'Mizoram'},
#  {'active': 18433,
#   'active_rate': 22.65,
#   'confirmed': 81379,
#   'death_rate': 2.04,
#   'deaths': 1661,
#   'recovered': 61285,
#   'recovered_rate': 75.31,
#   'state': 'Madhya Pradesh'},
#  {'active': 834,
#   'active_rate': 17.99,
#   'confirmed': 4636,
#   'death_rate': 0.22,
#   'deaths': 10,
#   'recovered': 3792,
#   'recovered_rate': 81.79,
#   'state': 'Nagaland'},
#  {'active': 30529,
#   'active_rate': 21.94,
#   'confirmed': 139121,
#   'death_rate': 0.42,
#   'deaths': 591,
#   'recovered': 108001,
#   'recovered_rate': 77.63,
#   'state': 'Odisha'},
#  {'active': 4794,
#   'active_rate': 25.86,
#   'confirmed': 18536,
#   'death_rate': 1.9,
#   'deaths': 353,
#   'recovered': 13389,
#   'recovered_rate': 72.23,
#   'state': 'Puducherry'},
#  {'active': 18088,
#   'active_rate': 25.07,
#   'confirmed': 72143,
#   'death_rate': 2.98,
#   'deaths': 2149,
#   'recovered': 51906,
#   'recovered_rate': 71.95,
#   'state': 'Punjab'},
#  {'active': 15702,
#   'active_rate': 16.13,
#   'confirmed': 97376,
#   'death_rate': 1.22,
#   'deaths': 1192,
#   'recovered': 80482,
#   'recovered_rate': 82.65,
#   'state': 'Rajasthan'},
#  {'active': 532,
#   'active_rate': 26.48,
#   'confirmed': 2009,
#   'death_rate': 0.35,
#   'deaths': 7,
#   'recovered': 1470,
#   'recovered_rate': 73.17,
#   'state': 'Sikkim'},
#  {'active': 48482,
#   'active_rate': 9.97,
#   'confirmed': 486052,
#   'death_rate': 1.68,
#   'deaths': 8154,
#   'recovered': 429416,
#   'recovered_rate': 88.35,
#   'state': 'Tamil Nadu'},
#  {'active': 32195,
#   'active_rate': 21.1,
#   'confirmed': 152602,
#   'death_rate': 0.62,
#   'deaths': 940,
#   'recovered': 119467,
#   'recovered_rate': 78.29,
#   'state': 'Telengana'},
#  {'active': 7383,
#   'active_rate': 41.45,
#   'confirmed': 17811,
#   'death_rate': 0.97,
#   'deaths': 173,
#   'recovered': 10255,
#   'recovered_rate': 57.58,
#   'state': 'Tripura'},
#  {'active': 66317,
#   'active_rate': 22.71,
#   'confirmed': 292029,
#   'death_rate': 1.44,
#   'deaths': 4206,
#   'recovered': 221506,
#   'recovered_rate': 75.85,
#   'state': 'Uttar Pradesh'},
#  {'active': 9106,
#   'active_rate': 32.22,
#   'confirmed': 28266,
#   'death_rate': 1.33,
#   'deaths': 377,
#   'recovered': 18783,
#   'recovered_rate': 66.45,
#   'state': 'Uttarakhand'},
#  {'active': 23377,
#   'active_rate': 12.1,
#   'confirmed': 193175,
#   'death_rate': 1.95,
#   'deaths': 3771,
#   'recovered': 166027,
#   'recovered_rate': 85.95,
#   'state': 'West Bengal'}]

# %%
states = []
deaths = []
recovered = []
confirmed = []
rec_rate = []
death_rate = []
for i in d[1]['state_data']:
    states.append(i['state'])
    deaths.append(i['deaths'])
    confirmed.append(i['confirmed'])
    recovered.append(i['recovered'])
    rec_rate.append(i['recovered_rate'])
    death_rate.append(i['death_rate'])

# %%
len(states)
# Out:
# 36

# %%
len(deaths)
# Out:
# 36

# %%
len(recovered)
# Out:
# 36

# %%
len(rec_rate)
# Out:
# 36

# %%
len(death_rate)
# Out:
# 36

# %%
len(confirmed)
# Out:
# 36

# %%
states_df = pd.DataFrame({"States":states,"Confirmed":confirmed,"Deaths":deaths,"Death_Rate":death_rate,"Recover_rate":rec_rate,"Recovered":recovered})

# %%
for i in states_df['States']:
    print(states_df[states_df['States'] == i].values)
# Out:
# [['Andaman and Nicobar' 3465 51 1.47 90.07 3121]]
# Int64Index([0], dtype='int64')
# [['Andhra Pradesh' 537687 4702 0.87 81.02 435647]]
# Int64Index([1], dtype='int64')
# [['Arunachal Pradesh' 5672 9 0.16 70.61 4005]]
# Int64Index([2], dtype='int64')
# [['Assam' 135805 414 0.3 77.83 105701]]
# Int64Index([3], dtype='int64')
# [['Bihar' 153568 785 0.51 89.57 137544]]
# Int64Index([4], dtype='int64')
# [['Chandigarh' 6987 83 1.19 61.99 4331]]
# Int64Index([5], dtype='int64')
# [['Chhattisgarh' 55680 493 0.89 46.43 25855]]
# Int64Index([6], dtype='int64')
# [['Dadra and Nagar Haveli and Daman and Diu' 2671 2 0.07 88.92 2375]]
# Int64Index([7], dtype='int64')
# [['Delhi' 205482 4666 2.27 85.36 175400]]
# Int64Index([8], dtype='int64')
# [['Goa' 22890 268 1.17 76.85 17592]]
# Int64Index([9], dtype='int64')
# [['Gujarat' 109465 3164 2.89 82.31 90103]]
# Int64Index([10], dtype='int64')
# [['Haryana' 85944 907 1.06 77.61 66705]]
# Int64Index([11], dtype='int64')
# [['Himachal Pradesh' 8466 66 0.78 67.06 5677]]
# Int64Index([12], dtype='int64')
# [['Jammu and Kashmir' 49134 845 1.72 69.64 34215]]
# Int64Index([13], dtype='int64')
# [['Jharkhand' 58079 517 0.89 72.51 42115]]
# Int64Index([14], dtype='int64')
# [['Karnataka' 430947 6937 1.61 74.82 322454]]
# Int64Index([15], dtype='int64')
# [['Kerala' 99266 396 0.4 73.11 72578]]
# Int64Index([16], dtype='int64')
# [['Ladakh' 3177 36 1.13 74.47 2366]]
# Int64Index([17], dtype='int64')
# [['Lakshadweep' 0 0 0.0 0.0 0]]
# Int64Index([18], dtype='int64')
# [['Maharashtra' 990795 28282 2.85 70.72 700715]]
# Int64Index([19], dtype='int64')
# [['Manipur' 7470 44 0.59 77.55 5793]]
# Int64Index([20], dtype='int64')
# [['Meghalaya' 3296 20 0.61 55.89 1842]]
# Int64Index([21], dtype='int64')
# [['Mizoram' 1333 0 0.0 56.26 750]]
# Int64Index([22], dtype='int64')
# [['Madhya Pradesh' 81379 1661 2.04 75.31 61285]]
# Int64Index([23], dtype='int64')
# [['Nagaland' 4636 10 0.22 81.79 3792]]
# Int64Index([24], dtype='int64')
# [['Odisha' 139121 591 0.42 77.63 108001]]
# Int64Index([25], dtype='int64')
# [['Puducherry' 18536 353 1.9 72.23 13389]]
# Int64Index([26], dtype='int64')
# [['Punjab' 72143 2149 2.98 71.95 51906]]
# Int64Index([27], dtype='int64')
# [['Rajasthan' 97376 1192 1.22 82.65 80482]]
# Int64Index([28], dtype='int64')
# [['Sikkim' 2009 7 0.35 73.17 1470]]
# Int64Index([29], dtype='int64')
# [['Tamil Nadu' 486052 8154 1.68 88.35 429416]]
# Int64Index([30], dtype='int64')
# [['Telengana' 152602 940 0.62 78.29 119467]]
# Int64Index([31], dtype='int64')
# [['Tripura' 17811 173 0.97 57.58 10255]]
# Int64Index([32], dtype='int64')
# [['Uttar Pradesh' 292029 4206 1.44 75.85 221506]]
# Int64Index([33], dtype='int64')
# [['Uttarakhand' 28266 377 1.33 66.45 18783]]
# Int64Index([34], dtype='int64')
# [['West Bengal' 193175 3771 1.95 85.95 166027]]
# Int64Index([35], dtype='int64')
