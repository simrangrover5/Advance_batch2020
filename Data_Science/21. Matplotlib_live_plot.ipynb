# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib.animation import FuncAnimation

# %%
# %matplotlib notebook

# %%
x = pd.date_range("20200116",periods=10)
y = list(np.random.randint(10,60,10))
fig,ax = plt.subplots()
ax.plot(x,y,'ro--')

def animate(w=None):
    print("hello")
    global y
    #ax.clear()
    y.pop(0)
    y.append(np.random.randint(10,60))
    ax.plot(x,y,'ro--')

f = FuncAnimation(fig,animate)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from time import sleep

x = pd.date_range("20200116",periods=10)
y = list(np.random.randint(10,60,10))
fig,ax = plt.subplots()
ax.plot(x,y,'ro--')

def animate(wait=None):
    global y
    ax.clear()
    sleep(wait)
    y.pop(0)
    y.append(np.random.randint(10,60))
    ax.plot(x,y,'ro--')

f = FuncAnimation(fig,animate,2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import psutil

# %%
psutil.cpu_count()
# Out:
# 8

# %%
psutil.cpu_freq()
# Out:
# scpufreq(current=1600.0, min=0.0, max=1800.0)

# %%
psutil.version_info()
# Out:
# (5, 6, 3)

# %%
psutil.virtual_memory()
# Out:
# svmem(total=8470630400, available=2732707840, percent=67.7, used=5737922560, free=2732707840)

# %%
psutil.cpu_stats()
# Out:
# scpustats(ctx_switches=92417287, interrupts=90399280, soft_interrupts=0, syscalls=526001053)

# %%
psutil.cpu_percent()
# Out:
# 23.1

# %%
psutil.cpu_times_percent()
# Out:
# scputimes(user=15.8, system=6.4, idle=77.3, interrupt=0.4, dpc=0.2)

# %%
for i in range(10):
    print("Cpu percent : ",psutil.cpu_percent())
# Out:
# Cpu percent :  17.7
# Cpu percent :  50.0
# Cpu percent :  0.0
# Cpu percent :  0.0
# Cpu percent :  0.0
# Cpu percent :  0.0
# Cpu percent :  0.0
# Cpu percent :  0.0
# Cpu percent :  0.0
# Cpu percent :  0.0

# %%
for i in range(10):
    sleep(2)
    print("Percentage : ",psutil.cpu_percent())
# Out:
# Percentage :  20.2
# Percentage :  21.4
# Percentage :  18.0
# Percentage :  19.3
# Percentage :  23.6
# Percentage :  18.8
# Percentage :  24.8
# Percentage :  15.8
# Percentage :  17.1
# Percentage :  21.1

# %%
x = list(range(50))
y = [psutil.cpu_percent() for i in range(50)]
fig = plt.figure(figsize=(10,5),facecolor="black")
ax = fig.add_axes([0,0,1,1],facecolor="black")
ax.plot(x,y,'ro--')
def animation(wait=None):
    global y
    ax.clear()
    y.pop(0)
    sleep(wait)
    y.append(psutil.cpu_percent())
    ax.plot(x,y,'wo--')
    
f = FuncAnimation(fig,animation,2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib inline

# %%
x = list(range(50))
y = [psutil.cpu_percent() for i in range(50)]
fig = plt.figure(figsize=(9,5),facecolor="black")
ax = fig.add_axes([0,0,1,1],facecolor="black")
ax.scatter(x,y)
ax.set_yticklabels(ax.get_yticks(),color="red")
plt.show()

# %%
# %matplotlib notebook

# %%
x = list(range(50))
y = [psutil.cpu_percent() for i in range(50)]
fig = plt.figure(figsize=(9,5),facecolor="black")
ax = fig.add_axes([0,0,1,1],facecolor="black")
ax.scatter(x,y)
ax.tick_params(axis="y",labelcolor="red")
def animation(wait=None):
    global y
    ax.clear()
    y.pop(0)
    sleep(wait)
    y.append(psutil.cpu_percent())
    ax.scatter(x,y)
    ax.tick_params(axis="y",labelcolor="red")
    
f = FuncAnimation(fig,animation,2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.6363636363636">

# %%
from time import sleep

x = pd.date_range("20200116",periods=10)
y = list(np.random.randint(10,60,10))
fig,ax = plt.subplots()
ax.plot(x,y,'ro--')

def animate(wait=None):
    global y
    ax.clear()
    sleep(wait)
    y.pop(0)
    y.append(np.random.randint(10,60))
    ax.plot(x,y,'ro--')

f = FuncAnimation(fig,animate,2)
plt.show()

# %%
x = pd.date_range("20200116",periods=10)

# %%
x
# Out:
# DatetimeIndex(['2020-01-16', '2020-01-17', '2020-01-18', '2020-01-19',
#                '2020-01-20', '2020-01-21', '2020-01-22', '2020-01-23',
#                '2020-01-24', '2020-01-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
x = [i.strftime("%d-%m") for i in x]

# %%
x
# Out:
# ['16-01',
#  '17-01',
#  '18-01',
#  '19-01',
#  '20-01',
#  '21-01',
#  '22-01',
#  '23-01',
#  '24-01',
#  '25-01']

# %%
from time import sleep

y = list(np.random.randint(10,60,10))
fig,ax = plt.subplots()
ax.plot(x,y,'ro--')

def animate(wait=None):
    global y
    ax.clear()
    sleep(wait)
    y.pop(0)
    y.append(np.random.randint(10,60))
    ax.plot(x,y,'ro--')

f = FuncAnimation(fig,animate,2)  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
### corona dataset , api --> live plot, twitter api
