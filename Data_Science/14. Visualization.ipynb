# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
num = np.linspace(1,10,20)

# %%
plt.plot(num,num**2)  #line

# %%
n = np.linspace(-5,5,20)

# %%
plt.plot(n)

# %%
plt.plot(n) #x --> index, y --> values(n)
plt.show()

# %%
plt.plot([2,3,4,5,2.5,6,1,1.3])
plt.show()

# %%
help(plt.plot)  #color marker linestyle
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.plot(n,color="red")
plt.show()

# %%
plt.plot(n,color="black")

# %%
plt.plot(n,color="#123456")

# %%
plt.rcParams.keys()
# Out:
# C:\Anaconda\lib\_collections_abc.py:705: MatplotlibDeprecationWarning:
# The examples.directory rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2. In the future, examples will be found relative to the 'datapath' directory.
#   return '{0.__class__.__name__}({0._mapping!r})'.format(self)
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
# ...

# %%
plt.rcParams['figure.figsize'] = [11,5]

# %%
plt.plot(n,color="black")
plt.show()

# %%
plt.plot(n,n**2,'ro')
plt.show()

# %%
plt.plot(n,n**2,'ro')
plt.plot(n,n**2,'k')
plt.show()

# %%
plt.plot(n,n**2,'ro')
plt.plot(n,n**2,'k')
plt.show()
plt.plot(n,n**3,'mh')
plt.show()

# %%
plt.plot(n,n**2,'ro')
plt.plot(n,n**2,'k')
plt.plot(n,n**3,'mh')
plt.show()

# %%
plt.plot(n,n**2,'ro--')
plt.show()

# %%
plt.plot(n,n**2,'ro-.')
plt.show()

# %%
plt.plot(n,n**2,'ro')
plt.plot(n,n**2,'b-.')
plt.show()

# %%
plt.plot(n,n**3,'rh--',ms=10)
plt.show()

# %%
plt.plot(n,n**3,'rh--',ms=10,markerfacecolor="black")
plt.show()

# %%
plt.plot(n,n**3,'rx:',ms=10,markeredgecolor="black",lw=3)
plt.show()

# %%
rad = np.linspace(0,2*np.pi,10)
sin = np.sin(rad)
cos = np.cos(rad)

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2)
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black")
plt.grid()
plt.show()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use("ggplot")

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2)
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black")
plt.show()

# %%
plt.style.use("dark_background")

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2)
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="white",markeredgecolor="white")
plt.show()

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2)
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="white",markeredgecolor="white")
plt.title("Sin(X) Cos(X)",fontsize=30,color="#abcdef",fontstyle="italic")
plt.show()

# %%
title = {"fontsize":35,"fontstyle":"italic","fontfamily":"monospace","color":"#abcdef"}
label = {"fontsize":20,"color":"white","fontfamily":"sans serif"}

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2)
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="white",markeredgecolor="white")
plt.title("Sin(X) Cos(X)",fontsize=30,color="#abcdef",fontstyle="italic")
plt.xlabel("Radian",fontdict=label)
plt.ylabel("sin(x) cos(x)",fontdict=label)
plt.show()

# %%
plt.style.use("seaborn-whitegrid")

# %%
plt.plot(n,n**2,color="red")
plt.show()

# %%
plt.plot(n,"*--",color="red",ms=15,markerfacecolor="black")
plt.xticks(range(0,20),fontsize=15,color="blue")
plt.yticks(range(-5,7),fontsize=15,color="#123456")
plt.grid(lw=2,color="gray",ls=":")
plt.show()

# %%
plt.plot(n,"*--",color="red",ms=15,markerfacecolor="black")
plt.xticks(range(0,20),fontsize=15,color="blue")
plt.yticks(range(-5,7),fontsize=15,color="#123456")
plt.grid(lw=2,color="gray",ls=":")
plt.tick_params(size=5,width=5)
plt.show()

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2,label="Sin(X)")
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black",label="Cos(X)")
plt.title("Sin(X) Cos(X)",fontsize=30,color="#123456",fontstyle="italic")
plt.xlabel("Radian",fontdict=label,color="#abc123")
plt.ylabel("sin(x) cos(x)",fontdict=label,color="#abc123")
plt.tick_params(labelcolor="orange",labelsize=20,size=5,width=8)
plt.grid(color="black")
plt.legend(fontsize=15)
plt.show()

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2,label="Sin(X)")
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black",label="Cos(X)")
plt.title("Sin(X) Cos(X)",fontsize=30,color="#123456",fontstyle="italic")
plt.xlabel("Radian",fontdict=label,color="#abc123")
plt.ylabel("sin(x) cos(x)",fontdict=label,color="#abc123")
plt.tick_params(labelcolor="orange",labelsize=20,size=5,width=8)
plt.grid(color="black")
plt.legend(loc=1,fontsize=15)
plt.show()

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2,label="Sin(X)")
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black",label="Cos(X)")
plt.title("Sin(X) Cos(X)",fontsize=30,color="#123456",fontstyle="italic")
plt.xlabel("Radian",fontdict=label,color="#abc123")
plt.ylabel("sin(x) cos(x)",fontdict=label,color="#abc123")
plt.tick_params(labelcolor="orange",labelsize=20,size=5,width=8)
plt.grid(color="black")
plt.legend(loc=2,fontsize=15)
plt.show()

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2,label="Sin(X)")
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black",label="Cos(X)")
plt.title("Sin(X) Cos(X)",fontsize=30,color="#123456",fontstyle="italic")
plt.xlabel("Radian",fontdict=label,color="#abc123")
plt.ylabel("sin(x) cos(x)",fontdict=label,color="#abc123")
plt.tick_params(labelcolor="orange",labelsize=20,size=5,width=8)
plt.grid(color="black")
plt.legend(loc=4,fontsize=15)
plt.show()

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2,label="Sin(X)")
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black",label="Cos(X)")
plt.title("Sin(X) Cos(X)",fontsize=30,color="#123456",fontstyle="italic")
plt.xlabel("Radian",fontdict=label,color="#abc123")
plt.ylabel("sin(x) cos(x)",fontdict=label,color="#abc123")
plt.tick_params(labelcolor="orange",labelsize=20,size=5,width=8)
plt.grid(color="black")
plt.legend(loc="center",fontsize=15)
plt.show()

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2,label="Sin(X)")
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black",label="Cos(X)")
plt.title("Sin(X) Cos(X)",fontsize=30,color="#123456",fontstyle="italic")
plt.xlabel("Radian",fontdict=label,color="#abc123")
plt.ylabel("sin(x) cos(x)",fontdict=label,color="#abc123")
plt.tick_params(labelcolor="orange",labelsize=20,size=5,width=8)
plt.grid(color="black")
plt.legend(loc="upper left",fontsize=15,edgecolor="red")
plt.show()

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2,label="Sin(X)")
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black",label="Cos(X)")
plt.title("Sin(X) Cos(X)",fontsize=30,color="#123456",fontstyle="italic")
plt.xlabel("Radian",fontdict=label,color="#abc123")
plt.ylabel("sin(x) cos(x)",fontdict=label,color="#abc123")
plt.tick_params(labelcolor="orange",labelsize=20,size=5,width=8)
plt.grid(color="black",lw=0.2)
plt.legend(loc="center",fontsize=15,edgecolor="red")
plt.show()

# %%
plt.plot(rad,sin,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2,label="Sin(X)")
plt.plot(rad,cos,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black",label="Cos(X)")
plt.title("Sin(X) Cos(X)",fontsize=30,color="#123456",fontstyle="italic")
plt.xlabel("Radian",fontdict=label,color="#abc123")
plt.ylabel("sin(x) cos(x)",fontdict=label,color="#abc123")
plt.tick_params(labelcolor="orange",labelsize=20,size=5,width=8)
plt.grid(color="black",lw=0.2)
plt.legend(loc=[0.55,0.4],fontsize=15,edgecolor="red")
plt.show()

# %%
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.left'] = False
plt.rcParams['axes.spines.bottom'] = False

# %%
plt.plot(n,n**2,'ro--',markersize=10,markerfacecolor="black",markeredgecolor="blue",lw=2,label="$X^2$")
plt.plot(n,n**3,'*-',markersize=10,markerfacecolor="black",markeredgecolor="black",label="$X^3$")
plt.title("$X^2 X^3$",fontsize=30,color="#123456",fontstyle="italic")
plt.xlabel("X",fontdict=label,color="#abc123")
plt.ylabel("$X^2 X^3$",fontdict=label,color="#abc123")
plt.tick_params(labelcolor="orange",labelsize=20,size=5,width=8)
plt.grid()
plt.legend(loc=[0.55,0.4],fontsize=15,edgecolor="red")
plt.show()

# %%
plt.plot(n,"red")
plt.scatter(n)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-436e6bf2c781> in <module>
#       1 plt.plot(n,"red")
# ----> 2 plt.scatter(n)
#       3 plt.show()
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
plt.plot(n,n**2,"--",color="red")
plt.scatter(n,n**2,color="black")
plt.show()

# %%
plt.plot(n,n**2,n,n**3,'r*:')
plt.show()

# %%
plt.plot(n,n**2,'bp--',n,n**3,'r*:',ms=10)
plt.show()

# %%
x = [3,4,5,6,7]
y = [1,2,5,3,6]
y1 = [3,4,1,5,6]
plt.plot(x,y,'r--')
plt.plot(x,y1,'g:')
plt.show()

# %%
x = [3,4,5,6,7]
y = [1,2,5,3,6]
y1 = [3,4,1,5,6]
plt.plot(x,y,'r--')
plt.plot(x,y1,'g:')
plt.fill_between(x,y,y1,color="black")
plt.show()

# %%
x = [3,4,5,6,7]
y = [1,2,5,3,6]
y1 = [3,4,1,5,6]
plt.plot(x,y,'r--')
plt.plot(x,y1,'g:')
plt.fill_between(x,y,x,y1,color="black")
plt.show()

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.scatter(iris['sepal_length'],iris['sepal_width'],color="black")
plt.show()

# %%
plt.scatter(iris['sepal_length'],iris['petal_length'],color="green")
plt.show()

# %%
plt.scatter(iris['sepal_width'],iris['petal_width'],color="green")
plt.show()

# %%
plt.plot(iris['sepal_width'],iris['petal_width'],'*',color="green")
plt.show()

# %%
plt.plot(iris['sepal_width'],iris['petal_width'],color="green")
plt.show()

# %%
plt.scatter(iris['sepal_width'],iris['petal_width'],color="green",s=18)
plt.show()

# %%
plt.scatter(iris['sepal_width'],iris['petal_width'],c=iris['species'],s=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4284             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4285                 colors = mcolors.to_rgba_array(c)
#    4286                 n_elem = colors.shape[0]
#
# C:\Anaconda\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     293     for i, cc in enumerate(c):
# --> 294         result[i] = to_rgba(cc, alpha)
#     295     return result
#
# C:\Anaconda\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#
# ...

# %%
iris['species'].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
iris['species'] = iris['species'].map({"versicolor":0,"setosa":1,"virginica":2})

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        1
# 1           4.9          3.0           1.4          0.2        1
# 2           4.7          3.2           1.3          0.2        1
# 3           4.6          3.1           1.5          0.2        1
# 4           5.0          3.6           1.4          0.2        1

# %%
plt.scatter(iris['sepal_width'],iris['petal_width'],c=iris['species'],s=28)
plt.show()

# %%
c = iris['species'].map({0:"red",1:"blue",2:"black"})

# %%
plt.scatter(iris['sepal_width'],iris['petal_width'],c=c,s=28)
plt.plot([],"r",label="(Versicolor)")
plt.plot([],"b",label="(Setosa)")
plt.plot([],"k",label="(Verginica)")
plt.legend(fontsize=15)
plt.show()
